# %%
from dataFile import *

# %%
total = 0
for currentLine in data:
    commonChar = ''.join(set(currentLine[:len(currentLine)//2]).intersection(currentLine[len(currentLine)//2:]))
    if commonChar.isupper():
        print (commonChar, ord(commonChar)-38)
        total += (ord(commonChar)-38)
    else:
        print (commonChar, ord(commonChar)-96)
        total += (ord(commonChar)-96)
# Out:
# s 19
# B 28
# m 13
# H 34
# b 2
# z 26
# j 10
# N 40
# C 29
# V 48
# H 34
# M 39
# C 29
# D 30
# d 4
# M 39
# T 46
# G 33
# P 42
# Q 43
# N 40
# F 32
# g 7
# V 48
# M 39
# C 29
# N 40
# F 32
# z 26
# M 39
# R 44
# B 28
# n 14
# l 12
# p 16
# D 30
# w 23
# H 34
# F 32
# c 3
# p 16
# N 40
# t 20
# b 2
# F 32
# V 48
# R 44
# q 17
# p 16
# L 38
# b 2
# r 18
# l 12
# c 3
# q 17
# p 16
# l 12
# F 32
# w 23
# v 22
# R 44
# w 23
# Q 43
# d 4
# f 6
# w 23
# L 38
# J 36
# z 26
# v 22
# T 46
# P 42
# q 17
# r 18
# D 30
# n 14
# D 30
# c 3
# f 6
# J 36
# V 48
# j 10
# S 45
# G 33
# C 29
# s 19
# p 16
# q 17
# C 29
# p 16
# z 26
# p 16
# w 23
# m 13
# t 20
# d 4
# V 48
# r 18
# l 12
# n 14
# q 17
# Q 43
# H 34
# c 3
# P 42
# z 26
# B 28
# H 34
# F 32
# v 22
# w 23
# l 12
# d 4
# g 7
# g 7
# p 16
# c 3
# R 44
# s 19
# w 23
# N 40
# t 20
# r 18
# l 12
# n 14
# c 3
# D 30
# l 12
# t 20
# c 3
# h 8
# z 26
# G 33
# l 12
# B 28
# N 40
# s 19
# R 44
# C 29
# H 34
# V 48
# R 44
# L 38
# r 18
# N 40
# ...

# %%
total
# Out:
# 7763

# %%
total = 0
prevSet = {}
for idx, currentLine in enumerate(data):
    commonChar = (set(currentLine))
    if idx % 3 == 0:
        prevSet = commonChar
    else: 
        prevSet = prevSet.intersection(commonChar)
    
    if idx % 3 == 2:
        #3rdtimes a charm....
        commonChar = ''.join(prevSet)
        if commonChar.isupper():
            print (commonChar, ord(commonChar)-38)
            total += (ord(commonChar)-38)
        else:
            print (commonChar, ord(commonChar)-96)
            total += (ord(commonChar)-96)
        
        prevSet = {}
# Out:
# v 22
# Q 43
# z 26
# g 7
# p 16
# v 22
# f 6
# c 3
# H 34
# m 13
# M 39
# N 40
# v 22
# B 28
# d 4
# c 3
# P 42
# f 6
# Z 52
# B 28
# V 48
# s 19
# q 17
# h 8
# Z 52
# R 44
# D 30
# W 49
# l 12
# w 23
# C 29
# C 29
# s 19
# R 44
# s 19
# J 36
# c 3
# F 32
# l 12
# Q 43
# p 16
# C 29
# H 34
# P 42
# b 2
# P 42
# R 44
# B 28
# w 23
# J 36
# J 36
# n 14
# q 17
# t 20
# r 18
# q 17
# c 3
# q 17
# W 49
# p 16
# B 28
# w 23
# j 10
# b 2
# R 44
# C 29
# P 42
# w 23
# h 8
# j 10
# B 28
# F 32
# R 44
# L 38
# h 8
# t 20
# D 30
# P 42
# B 28
# b 2
# M 39
# d 4
# m 13
# z 26
# N 40
# Z 52
# s 19
# s 19
# t 20
# l 12
# G 33
# f 6
# J 36
# T 46
# F 32
# N 40
# q 17
# M 39
# t 20
# L 38

# %%
total
# Out:
# 2569
